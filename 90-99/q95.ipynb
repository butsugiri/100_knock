# %% [markdown]
# # q95
#
# ## WordSimilarity-353での評価
# 94で作ったデータを用い，各モデルが出力する類似度のランキングと，人間の類似度判定のランキングの間のスピアマン相関係数を計算せよ．

# %%
import pandas as pd
# %matplotlib inline

# %%
df_q85 = pd.read_table("./data/q94_q85_result.log", header=None,usecols=[2,3],names = ["human score","q85_model"])
df_q85.corr()
# Out:
#              human score  q85_model
# human score     1.000000   0.517663
# q85_model       0.517663   1.000000

# %%
df_q90 = pd.read_table("./data/q94_q90_result.log", header=None,usecols=[2,3],names = ["human score","q90_model"])
df_q90.corr()
# Out:
#              human score  q90_model
# human score      1.00000    0.69032
# q90_model        0.69032    1.00000

# %% [markdown]
# 調子に乗ったのでプロットまでしてみる

# %%
df_q85.plot.scatter(x="human score", y="q85_model")

# %%
df_q90.plot.scatter(x="human score", y="q90_model")
